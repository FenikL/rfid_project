# %%
# %load_ext autoreload

# %autoreload 2

from tqdm.notebook import trange, tqdm
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import namedtuple
from model import model
from model import variables
from model import snr_to_ber
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
res_tari_625_m_1_tid_off = [model.run_model(velocity=v, q_bit=0, tid_is_on=False,
              tari=6.25, num_of_sym_per_bit=1, trext=0) for v in tqdm(range(13, 50, 2))]
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]

# %%
res_tari_625_m_1_tid_off
# Out:
# [ProbRet(velocity=13, probability=0.8866666666666666, num_cars=1.0, num_rounds=1648.58, round_duration=0.0005323526762524004),
#  ProbRet(velocity=15, probability=0.8133333333333335, num_cars=1.0, num_rounds=1428.8466666666666, round_duration=0.0004907305864938624),
#  ProbRet(velocity=17, probability=0.7866666666666666, num_cars=1.0, num_rounds=1260.4333333333334, round_duration=0.00046104196754737016),
#  ProbRet(velocity=19, probability=0.7733333333333333, num_cars=1.0, num_rounds=1127.7733333333333, round_duration=0.0004386855670589927),
#  ProbRet(velocity=21, probability=0.7333333333333333, num_cars=1.0, num_rounds=1020.5333333333333, round_duration=0.0004212562338549211),
#  ProbRet(velocity=23, probability=0.7133333333333333, num_cars=1.0, num_rounds=931.4666666666667, round_duration=0.00040736324181569485),
#  ProbRet(velocity=25, probability=0.6666666666666667, num_cars=1.0, num_rounds=856.9066666666666, round_duration=0.0003959698320101076),
#  ProbRet(velocity=27, probability=0.6133333333333334, num_cars=1.0, num_rounds=793.6333333333333, round_duration=0.0003864279369610362),
#  ProbRet(velocity=29, probability=0.6066666666666667, num_cars=1.0, num_rounds=739.1933333333333, round_duration=0.00037833528168309443),
#  ProbRet(velocity=31, probability=0.5533333333333332, num_cars=1.0, num_rounds=691.3000000000001, round_duration=0.0003714789700724458),
#  ProbRet(velocity=33, probability=0.5, num_cars=1.0, num_rounds=649.42, round_duration=0.00036550760347469534),
#  ProbRet(velocity=35, probability=0.5466666666666667, num_cars=1.0, num_rounds=612.3533333333334, round_duration=0.00036026094955255247),
#  ProbRet(velocity=37, probability=0.48, num_cars=1.0, num_rounds=579.3933333333333, round_duration=0.00035560981243655656),
#  ProbRet(velocity=39, probability=0.46666666666666673, num_cars=1.0, num_rounds=549.6466666666666, round_duration=0.00035152548538519964),
#  ProbRet(velocity=41, probability=0.4933333333333333, num_cars=1.0, num_rounds=522.9266666666667, round_duration=0.0003478241080130157),
#  ProbRet(velocity=43, probability=0.42, num_cars=1.0, num_rounds=498.68, round_duration=0.0003445005939703288),
#  ProbRet(velocity=45, probability=0.44, num_cars=1.0, num_rounds=476.39333333333326, round_duration=0.00034154095500193575),
#  ProbRet(velocity=47, probability=0.4066666666666666, num_cars=1.0, num_rounds=456.3066666666667, round_duration=0.000338793151443244),
#  ProbRet(velocity=49, probability=0.3466666666666666, num_cars=1.0, num_rounds=437.44000000000005, round_duration=0.00033635407836319535)]

# %%
res_tari_625_m_1_tid_off
# Out:
# [ProbRet(velocity=13, probability=0.85, num_cars=1.0, num_rounds=1648.4099999999999, round_duration=0.000532428364483554),
#  ProbRet(velocity=15, probability=0.8533333333333333, num_cars=1.0, num_rounds=1428.7066666666667, round_duration=0.0004907653740458393),
#  ProbRet(velocity=17, probability=0.8066666666666668, num_cars=1.0, num_rounds=1260.6899999999998, round_duration=0.00046097184895353943),
#  ProbRet(velocity=19, probability=0.75, num_cars=1.0, num_rounds=1128.03, round_duration=0.00043861723428735284),
#  ProbRet(velocity=21, probability=0.6533333333333333, num_cars=1.0, num_rounds=1020.71, round_duration=0.00042121013251518056),
#  ProbRet(velocity=23, probability=0.6366666666666667, num_cars=1.0, num_rounds=931.5633333333334, round_duration=0.000407367102131572),
#  ProbRet(velocity=25, probability=0.6166666666666667, num_cars=1.0, num_rounds=857.1733333333333, round_duration=0.00039593173586565105),
#  ProbRet(velocity=27, probability=0.5733333333333333, num_cars=1.0, num_rounds=794.0666666666666, round_duration=0.0003863630118459459),
#  ProbRet(velocity=29, probability=0.5566666666666668, num_cars=1.0, num_rounds=739.0233333333334, round_duration=0.00037837288183821375),
#  ProbRet(velocity=31, probability=0.5466666666666666, num_cars=1.0, num_rounds=691.48, round_duration=0.00037144692886500704),
#  ProbRet(velocity=33, probability=0.5633333333333334, num_cars=1.0, num_rounds=649.64, round_duration=0.00036545667394413987),
#  ProbRet(velocity=35, probability=0.56, num_cars=1.0, num_rounds=612.4533333333334, round_duration=0.0003602459381788295),
#  ProbRet(velocity=37, probability=0.5166666666666666, num_cars=1.0, num_rounds=579.45, round_duration=0.00035560692413344453),
#  ProbRet(velocity=39, probability=0.46333333333333343, num_cars=1.0, num_rounds=549.6233333333333, round_duration=0.0003515229899593109),
#  ProbRet(velocity=41, probability=0.45, num_cars=1.0, num_rounds=522.84, round_duration=0.0003478514413974148),
#  ProbRet(velocity=43, probability=0.45333333333333337, num_cars=1.0, num_rounds=498.77, round_duration=0.0003445016558892885),
#  ProbRet(velocity=45, probability=0.46999999999999986, num_cars=1.0, num_rounds=476.38999999999993, round_duration=0.00034153860658755314),
#  ProbRet(velocity=47, probability=0.39666666666666667, num_cars=1.0, num_rounds=456.0733333333333, round_duration=0.0003388260017132178),
#  ProbRet(velocity=49, probability=0.39333333333333337, num_cars=1.0, num_rounds=437.67, round_duration=0.00033631823838769896)]

# %%
df_tari_625_m1_tid_off = pd.DataFrame(data=res_tari_625_m_1_tid_off)

# %%
df_tari_625_m1_tid_off.to_csv('data/tari_625_m1_tid_off.csv')

# %%
df_tari_625_m1_tid_off.plot(x='velocity', y='probability', grid=True)
# Out:
# <AxesSubplot:xlabel='velocity'>
