# %%
# %load_ext autoreload

# %autoreload 2

from tqdm import tqdm
import csv
import pandas as pd
import matplotlib.pyplot as plt

from collections import namedtuple

from model import model
from model import variables
from model import snr_to_ber

# %%
VariablesByTari = namedtuple('VariablesByTari', ['trcal', 'rtcal',
                             'blf', 't1_and_t2', 't1_and_t3'])
Bitrate = namedtuple('Bitrate', ['reader_bitrate', 'tag_bitrate'])
Preamble = namedtuple('Preamble', ['t_sync_preamble', 't_full_preamble', 'tag_preamble_len'])

# %%
def get_preamble_duration(m, tari, trext):
    variables_by_tari = variables.get_variables_from_tari(tari)
    bitrate = variables.get_bitrate(variables_by_tari.rtcal,
                                    variables_by_tari.blf,
                                    m)
    preamble = variables.get_preamble(tari,
                                      variables_by_tari.rtcal,
                                      variables_by_tari.trcal,
                                      trext, m)
    return preamble.tag_preamble_len / bitrate.tag_bitrate

def get_blf(tari):
    variables_by_tari = variables.get_variables_from_tari(tari)
    return variables_by_tari.blf

# %%
rx_power = [dbm for dbm in range(-110, -50)]

# %%
tari = 6.25
m = 1
trext = 0
BER1 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 6.25
m = 2
trext = 0
BER2 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 6.25
m = 4
trext = 0
BER3 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 6.25
m = 8
trext = 0
BER4 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 12.5
m = 1
trext = 0
BER5 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 12.5
m = 2
trext = 0
BER6 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 12.5
m = 4
trext = 0
BER7 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 12.5
m = 8
trext = 0
BER8 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 18.75
m = 1
trext = 0
BER9 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 18.75
m = 2
trext = 0
BER10 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 18.75
m = 4
trext = 0
BER11 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 18.75
m = 8
trext = 0
BER12 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 25
m = 1
trext = 0
BER13 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 25
m = 2
trext = 0
BER14 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 25
m = 4
trext = 0
BER15 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]
tari = 25
m = 8
trext = 0
BER16 = [snr_to_ber.ber_over_awgn(snr_to_ber.get_snr(rx_power=dbm, m=m, preamble_duration=get_preamble_duration(m, tari, trext), blf=get_blf(tari))) for dbm in rx_power]

# %%
ax = plt.subplot()
line_ber1 = ax.plot(rx_power, BER1, marker = 's',linewidth = 1,markersize=5, label='Tari = 6.25, FM0')
line_ber2 = ax.plot(rx_power, BER2, marker = 'v',linewidth = 1,markersize=5,  label='Tari = 6.25, M2')
line_ber3 = ax.plot(rx_power, BER3, marker = '1',linewidth = 1,markersize=5,  label='Tari = 6.25, M4')
line_ber4 = ax.plot(rx_power, BER4, marker = '^',linewidth = 1,markersize=5,  label='Tari = 6.25, M8')
line_ber1 = ax.plot(rx_power, BER5, marker = '<',linewidth = 1,markersize=5,  label='Tari = 12.5, FM0')
line_ber2 = ax.plot(rx_power, BER6, marker = '>',linewidth = 1, markersize=5, label='Tari = 12.5, M2')
line_ber3 = ax.plot(rx_power, BER7, marker = 'p',linewidth = 1,markersize=5,  label='Tari = 12.5, M4')
line_ber4 = ax.plot(rx_power, BER8, linestyle = ':',linewidth = 1, markersize=5, label='Tari = 12.5, M8')
line_ber1 = ax.plot(rx_power, BER9, linestyle = '-', linewidth = 1,markersize=5, label='Tari = 18.75, FM0')
line_ber2 = ax.plot(rx_power, BER10, linestyle = '-.',linewidth = 1,markersize=5,  label='Tari = 18.75, M2')
line_ber3 = ax.plot(rx_power, BER11, linestyle = '--',linewidth = 1, markersize=5, label='Tari = 18.75, M4')
line_ber4 = ax.plot(rx_power, BER12,  label='Tari = 18.75, M8')
line_ber1 = ax.plot(rx_power, BER13, label='Tari = 25, FM0')
line_ber2 = ax.plot(rx_power, BER14, label='Tari = 25, M2')
line_ber3 = ax.plot(rx_power, BER15,  label='Tari = 25, M4')
line_ber4 = ax.plot(rx_power, BER16, label='Tari = 25, M8')
leg = ax.legend(bbox_to_anchor=(1.05, 1) ,loc='upper left', borderaxespad=0.)
ax.grid()
plt.title('BER for AWGN. DR=64/3, TRext=0')
ax.set_xlabel('RX power, dBm')
ax.set_ylabel('BER')
plt.show()

# %%
snr = pd.DataFrame()
snr["rx power"] = rx_power
snr["Tari = 6.25, FM0"] = BER1
snr["Tari = 6.25, M2"] = BER2
snr["Tari = 6.25, M4"] = BER3
snr["Tari = 6.25, M8"] = BER4
snr["Tari = 12.5, FM0"] = BER5
snr["Tari = 12.5, M2"] = BER6
snr["Tari = 12.5, M4"] = BER7
snr["Tari = 12.5, M8"] = BER8
snr["Tari = 18.75, FM0"] = BER9
snr["Tari = 18.75, M2"] = BER10
snr["Tari = 18.75, M4"] = BER11
snr["Tari = 18.75, M8"] = BER12
snr["Tari = 25, FM0"] = BER13
snr["Tari = 25, M2"] = BER14
snr["Tari = 25, M4"] = BER15
snr["Tari = 25, M8"] = BER16

# %%
snr
# Out:
#     rx power  Tari = 6.25, FM0  Tari = 6.25, M2  Tari = 6.25, M4  \
# 0       -110      4.996648e-01     4.995468e-01     4.999665e-01
# 1       -109      4.999810e-01     4.991736e-01     4.997780e-01
# 2       -108      4.996212e-01     4.994962e-01     4.988159e-01
# 3       -107      4.994968e-01     4.999641e-01     4.975737e-01
# 4       -106      4.999944e-01     4.997844e-01     4.966576e-01
# 5       -105      4.994743e-01     4.988283e-01     4.964218e-01
# 6       -104      4.986672e-01     4.975858e-01     4.968874e-01
# 7       -103      4.989606e-01     4.966639e-01     4.978297e-01
# 8       -102      4.998216e-01     4.964204e-01     4.989034e-01
# 9       -101      4.998371e-01     4.968796e-01     4.997378e-01
# 10      -100      4.984936e-01     4.978187e-01     4.999876e-01
# 11       -99      4.964408e-01     4.988930e-01     4.993473e-01
# 12       -98      4.947157e-01     4.997316e-01     4.975441e-01
# ...
